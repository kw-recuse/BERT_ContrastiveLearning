# %%
# !git clone https://github.com/kw-recuse/BERT_ContrastiveLearning.git
# Out:
# Cloning into 'BERT_ContrastiveLearning'...
# remote: Enumerating objects: 235, done.
# remote: Counting objects: 100% (235/235), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 235 (delta 114), reused 198 (delta 79), pack-reused 0 (from 0)
# Receiving objects: 100% (235/235), 44.82 KiB | 14.94 MiB/s, done.
# Resolving deltas: 100% (114/114), done.

# %%
# Change to the repository directory
# %cd BERT_ContrastiveLearning
# Out:
# /content/BERT_ContrastiveLearning

# %%
import sys
sys.path.append('/content/BERT_ContrastiveLearning')

# %%
from scripts.train import Trainer

trainer = Trainer(
    config_file="/content/BERT_ContrastiveLearning/configs/train/multiling_BERT.json",
    checkpoints_path="/content/checkpoints",
    csv_file_path="/content/output_file.csv",
    col_name1='resume',
    col_name2='jd',
    label_col='label'
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/531 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/610 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/539M [00:00<?, ?B/s]
# Training pairs: 28168, Validation pairs: 872
# /content/BERT_ContrastiveLearning/scripts/train.py:48: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = GradScaler()

# %%
# Start training
trainer.train()
# Out:
# Epoch 1:   0%|          | 0/3521 [00:00<?, ?it/s]
# /content/BERT_ContrastiveLearning/scripts/train.py:142: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /content/BERT_ContrastiveLearning/scripts/train.py:108: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1, Step 1 - Avg Validation Loss: 0.3017
# Checkpoint saved at /content/checkpoints/epoch1_step1_loss0.30165217.pt
# Epoch 1, Step 704 - Avg Validation Loss: 0.1174
# Checkpoint saved at /content/checkpoints/epoch1_step704_loss0.11736591.pt
# Epoch 1, Step 1408 - Avg Validation Loss: 0.1126
# Checkpoint saved at /content/checkpoints/epoch1_step1408_loss0.1125756.pt
# Epoch 1, Step 2112 - Avg Validation Loss: 0.1098
# Checkpoint saved at /content/checkpoints/epoch1_step2112_loss0.10978403.pt
# Epoch 1, Step 2816 - Avg Validation Loss: 0.1077
# Checkpoint saved at /content/checkpoints/epoch1_step2816_loss0.10771651.pt
# Epoch 1, Step 3520 - Avg Validation Loss: 0.1084
# Checkpoint saved at /content/checkpoints/epoch1_step3520_loss0.10838732.pt
# Epoch 1, Step 3521 - Avg Validation Loss: 0.1084
# Checkpoint saved at /content/checkpoints/epoch1_step3521_loss0.10838264.pt
# Epoch 2:   0%|          | 0/3521 [00:00<?, ?it/s]
# Epoch 2, Step 1 - Avg Validation Loss: 0.1083
# Checkpoint saved at /content/checkpoints/epoch2_step1_loss0.10829707.pt
# Epoch 2, Step 704 - Avg Validation Loss: 0.1100
# Checkpoint saved at /content/checkpoints/epoch2_step704_loss0.11003352.pt
# Epoch 2, Step 1408 - Avg Validation Loss: 0.1055
# Checkpoint saved at /content/checkpoints/epoch2_step1408_loss0.10553189.pt
# Epoch 2, Step 2112 - Avg Validation Loss: 0.1097
# Checkpoint saved at /content/checkpoints/epoch2_step2112_loss0.10973085.pt
# Epoch 2, Step 2816 - Avg Validation Loss: 0.1108
# Checkpoint saved at /content/checkpoints/epoch2_step2816_loss0.11079867.pt
# Epoch 2, Step 3520 - Avg Validation Loss: 0.1090
# Checkpoint saved at /content/checkpoints/epoch2_step3520_loss0.1090396.pt
# Epoch 2, Step 3521 - Avg Validation Loss: 0.1092
# Checkpoint saved at /content/checkpoints/epoch2_step3521_loss0.10921359.pt
# Epoch 3:   0%|          | 0/3521 [00:00<?, ?it/s]
# Epoch 3, Step 1 - Avg Validation Loss: 0.1094
# Checkpoint saved at /content/checkpoints/epoch3_step1_loss0.1093571.pt
# No improvement in validation loss for 5 steps. STOPPED TRAINING
